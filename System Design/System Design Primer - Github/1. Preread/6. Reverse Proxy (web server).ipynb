# %% [markdown]
# # Reverse Proxy

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Proxy server that sits between internal and external systems. It can provide:
#     - Security: Hides information about backend servers, blacklist IPs, limit number of connections per client
#     - Scalability/flexibility: Clients only call the reverse proxy's IP, so clients don't need to care about how your backend changes/scales.
#     - SSL termination: Decrypt incoming requests + encrypt server responses, so your servers don't have to install X.509 certificates (else managing certificates for all servers is tedious)
#     - Compress server responses
#     - Caching of common requests
#     - Serve static content directly

# %% [markdown]
# - From the list above, it seems like a reverse proxy is very similar to a load balancer
#     - They are not mutually exclusive
#     - Load balancers are chiefly useful when you have multiple servers, but reverse proxy can be useful with 1 server
#     - Solutions such as NGINX and HAProxy support both layer 7 reverse proxying and load balancing.
#
#     - To be honest, they are pretty much the same thing. All the benefits of both reverse proxy and load balancers are derived from a "server-in-the-middle" architecture.

# %% [markdown]
# ## Disadvantage

# %% [markdown]
# - Introducing a reverse proxy results in increased complexity.
# - A single reverse proxy is a single point of failure, configuring multiple reverse proxies (ie a failover) further increases complexity.
